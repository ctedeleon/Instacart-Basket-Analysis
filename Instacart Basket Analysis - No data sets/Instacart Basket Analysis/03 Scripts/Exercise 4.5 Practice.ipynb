# %% [markdown]
# # Importing libraries and data sets

# %%
import pandas as pd
import numpy as np
import os 

path = r'C:\Users\ctede\OneDrive\Desktop\Instacart Basket Analysis'
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'))
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'))

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# # Create a test dataframe

# %%
#Create a dataframe
df_test = pd.DataFrame()

# %%
#Create a mixed type column 
df_test['mix'] = ['a','b', 1, True]

# %%
df_test
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %% [markdown]
# # Check for mixed data types

# %%
for col in df_test.columns.tolist(): 
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis=1)
    if len (df_test[weird]) > 0: 
        print(col)
# Out:
# mix

# %% [markdown]
# ### Change from numeric to string data type

# %%
df_test['mix'] = df_test['mix'].astype('str')

# %%
df_test['mix'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Re-import libraries and dataframes

# %%
import pandas as pd
import numpy as np
import os 

path = r'C:\Users\ctede\OneDrive\Desktop\Instacart Basket Analysis'
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'))
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# ### Finding missing values

# %%
#Sum the number of missing values in each column
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %% [markdown]
# ### View the missing values in the product_name column

# %%
#Create a subset to view the missing/null values in the product_name column 
#isnull() == True is a condition for displaying only when there are null (missing) values
df_nan = df_prods[df_prods['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %% [markdown]
# ### View the number of rows, columns of the products dataframe

# %%
df_prods.shape
# Out:
# (49693, 5)

# %% [markdown]
# ### Create a new/clean dataframe that excludes the missing values

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull()==False]

# %%
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#Show number of rows/columns of df_prods_clean 
df_prods_clean.shape
# Out:
# (49677, 5)

# %% [markdown]
# # Finding full duplicates

# %%
#Creating a subset that has all full duplicates 
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %% [markdown]
# # Dropping full duplicates

# %%
#Drop duplicates and create a new clean (no duplicates) dataframe 
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# # Task 4.5 Consistency Checks on df_ords

# %% [markdown]
# ### Import libraries and datasets

# %%
import pandas as pd
import numpy as np
import os 

path = r'C:\Users\ctede\OneDrive\Desktop\Instacart Basket Analysis'
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %% [markdown]
# ### 2 Run the df.describe() function on df_ords. Share whether anything about the data looks off or should be investigated further.

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# ...

# %%
df_ords = pd.read_csv(r'C:\Users\ctede\OneDrive\Desktop\Instacart Basket Analysis\02 Data\Prepared Data\orders_wrangled.csv', index_col = False)

# %%
df_ords
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                 0   2539329        1    prior             1          2
# 1                 1   2398795        1    prior             2          3
# 2                 2    473747        1    prior             3          3
# 3                 3   2254736        1    prior             4          4
# 4                 4    431534        1    prior             5          4
# ...             ...       ...      ...      ...           ...        ...
# 3421078     3421078   2266710   206209    prior            10          5
# 3421079     3421079   1854736   206209    prior            11          4
# 3421080     3421080    626363   206209    prior            12          1
# 3421081     3421081   2977660   206209    prior            13          1
# 3421082     3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# #### The order_id and user_id columns are expected to contain what look like random numbers because these columns contain identifying/unique values. I do not see any negative numbers in any of the columns. The order_dow (day of the week) statistics make sense. The maximum and minimum correspond with what is listed on the project brief (Friday and Saturday). The order_hour_of_day statistics have times less than 24 hours. The minimum 0 hours should correspond to 12am (midnight) and the maximum 23 hours should correspond to 11pm. Lastly, the days_since_prior_order statistics also make sense (can have a value of 0 days since prior order if the customer is purchasing back to back orders). There does not seem to be any outliers or extreme values that affect the averages of each column.

# %% [markdown]
# ### 3 Check for mixed-type data in df_ords.

# %%
for col in df_ords.columns.tolist(): 
    weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis=1)
    if len (df_ords[weird]) > 0: 
        print(col)

# %% [markdown]
# #### After running the above code on the df_ords dataframe (provided from the example for df_test), there was no output / no columns were printed. This means that there are no mixed data types in the columns/variables for the orders dataframe and that each column contains consistent data types.

# %%
#Show data types for each column in the orders dataframe
df_ords.dtypes
# Out:
# Unnamed: 0                  int64
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# ### 5 Run a check for missing values in df_ords. Report your findings and propose an explanation for any missing values found.

# %%
#Sum the number of missing values in each column
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
#View the missing values
df_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]
df_nan
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                 0   2539329        1    prior             1          2
# 11               11   2168274        2    prior             1          2
# 26               26   1374495        3    prior             1          1
# 39               39   3343014        4    prior             1          6
# 45               45   2717275        5    prior             1          3
# ...             ...       ...      ...      ...           ...        ...
# 3420930     3420930    969311   206205    prior             1          4
# 3420934     3420934   3189322   206206    prior             1          3
# 3421002     3421002   2166133   206207    prior             1          6
# 3421019     3421019   2227043   206208    prior             1          1
# 3421069     3421069   3154581   206209    prior             1          3
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
df_ords.shape
# Out:
# (3421083, 8)

# %% [markdown]
# #### The "days since prior order" column has 206209 missing values (nulls). This column describes the number of days between the current order and a previous order. If a customer is ordering every single day, then the expected value is 0. Each of these missing values have the same order_number (1) and the user_id associated with each missing value is in numerical order.

# %%
#Look at another user_id
df_ords[df_ords['user_id']==2]
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 11          11   2168274        2    prior             1          2
# 12          12   1501582        2    prior             2          5
# 13          13   1901567        2    prior             3          1
# 14          14    738281        2    prior             4          2
# 15          15   1673511        2    prior             5          3
# 16          16   1199898        2    prior             6          2
# 17          17   3194192        2    prior             7          2
# 18          18    788338        2    prior             8          1
# 19          19   1718559        2    prior             9          2
# 20          20   1447487        2    prior            10          1
# 21          21   1402090        2    prior            11          1
# 22          22   3186735        2    prior            12          1
# 23          23   3268552        2    prior            13          4
# ...

# %% [markdown]
# #### The first order number for each user_id will have a missing value in the days_since_prior_order column because there are no orders that precede the very first order. We should expect to see a "NaN" value for the first order for each user_id.

# %%
#Look at another user_id
df_ords[df_ords['user_id']==5]
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 45          45   2717275        5    prior             1          3
# 46          46   1909121        5    prior             2          0
# 47          47   2267326        5    prior             3          3
# 48          48    157374        5    prior             4          1
# 49          49   2196797        5    train             5          0
#
#     order_hour_of_day  days_since_prior_order
# 45                 12                     NaN
# 46                 16                    11.0
# 47                 18                    10.0
# 48                 18                    19.0
# 49                 11                     6.0

# %% [markdown]
# ### 6 Solution: impute a "0" to represent the first order (that there were zero days since previous order).

# %%
#Impute "0" for the days_since_prior_order column for the first order_number of each customer. 
#To represent there were zero (0) days since prior order. 
df_ords['days_since_prior_order'].fillna(0, inplace=True)

# %%
df_ords[df_ords['user_id']==5]
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 45          45   2717275        5    prior             1          3
# 46          46   1909121        5    prior             2          0
# 47          47   2267326        5    prior             3          3
# 48          48    157374        5    prior             4          1
# 49          49   2196797        5    train             5          0
#
#     order_hour_of_day  days_since_prior_order
# 45                 12                     0.0
# 46                 16                    11.0
# 47                 18                    10.0
# 48                 18                    19.0
# 49                 11                     6.0

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.421083e+06
# mean        1.345202e+01            1.044488e+01
# std         4.226088e+00            9.308727e+00
# min         0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# ### 7 Run a check for duplicate values in df_ords

# %%
df_dups = df_ords[df_ords.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# #### There are no full duplicates in the orders dataframe.
