# %% [markdown]
# # Import libraries and datasets

# %%
import pandas as pd
import numpy as np 
import os 

path = r'C:\Users\ctede\OneDrive\Desktop\Instacart Basket Analysis'

# %% [markdown]
# ## 3 Import the orders_products_combined dataframe that you just saved

# %%
#import the orders and products combined dataset 
df_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ## 4 Check the shape of the imported dataframe (it should be the same as the one you exported)

# %%
df_merged.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ## 5 Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you are using your wrangled, clean, and deduped products data set stored in your "Prepared Data" forlder.

# %%
#import the clean products dataset 
df_prods_clean = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_full_clean.csv'), index_col=[0])

# %%
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     0.0         196                  1          0   both
# 1                     0.0       14084                  2          0   both
# 2                     0.0       12427                  3          0   both
# 3                     0.0       26088                  4          0   both
# 4                     0.0       26405                  5          0   both

# %% [markdown]
# ### The common variable / key between the merged df and the clean products df is the "product_id" variable. I want to import the clean products df onto the merged df using the "product_id". The number of columns do not match (the clean products df has 5 columns and the merged df has 11 columns). So, I think using the df.merge() function is best.

# %%
#Test the merge without overwriting. The merge flag is already included in the merged dataframe. 
#Did not have to include the merge flag in the test.
pd.merge(df_merged, df_prods_clean, on = ['product_id'])
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     0.0         196
# 1                         7                    15.0         196
# ...

# %%
#Create the fully combined/merged dataframe: df_ords_prods_merged
df_ords_prods_merged = df_merged.merge(df_prods_clean, on = 'product_id')

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     0.0         196
# 1                         7                    15.0         196
# ...

# %% [markdown]
# ## 7 Export the newly created dataframe as orders_products_merged in a suitable format.

# %%
#Export as pickle file 
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
